# %%
import numpy as np

# %%
tech_companies=np.array([('IBM','TCS','Wipro','Infosys','NTT Data','Capgemini'),
                        ('Bangalore','Andheri','Pune','Mangalore','Pune','Pune')])

# %%
tech_companies.shape
# Out:
# (2, 6)

# %%
tech_companies.ravel()
# Out:
# array(['IBM', 'TCS', 'Wipro', 'Infosys', 'NTT Data', 'Capgemini',
#        'Bangalore', 'Andheri', 'Pune', 'Mangalore', 'Pune', 'Pune'],
#       dtype='<U9')

# %%
tech_companies.T.flatten()
# Out:
# array(['IBM', 'Bangalore', 'TCS', 'Andheri', 'Wipro', 'Pune', 'Infosys',
#        'Mangalore', 'NTT Data', 'Pune', 'Capgemini', 'Pune'], dtype='<U9')

# %%
tech_companies.reshape(-1,4)            # no. of Row could be anything but column has to be 4
# Out:
# array([['IBM', 'TCS', 'Wipro', 'Infosys'],
#        ['NTT Data', 'Capgemini', 'Bangalore', 'Andheri'],
#        ['Pune', 'Mangalore', 'Pune', 'Pune']], dtype='<U9')

# %%
tech_companies.reshape(4,-1)   # no. of Column could be anything but Row has to be 4
# Out:
# array([['IBM', 'TCS', 'Wipro'],
#        ['Infosys', 'NTT Data', 'Capgemini'],
#        ['Bangalore', 'Andheri', 'Pune'],
#        ['Mangalore', 'Pune', 'Pune']], dtype='<U9')
